# %%
import pandas

# %%
df = pandas.read_csv("supermarkets.csv")

# %%
df.set_index("ID", inplace=True)
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
import geopy
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
df["Address"]=df["Address"]+", "+df["City"]+", "+df["State"]
df
# Out:
#                                          Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119  San Francisco
# 3   332 Hill St, San Francisco, California 94114  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114  San Francisco
# 5     1056 Sanchez St, San Francisco, California  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114  San Francisco
#
#                State Country         Name  Employees
# ID
# 1           CA 94114     USA      Madeira          8
# 2           CA 94119     USA  Bready Shop         15
# 3   California 94114     USA  Super River         25
# 4           CA 94114     USA   Ben's Shop         10
# 5         California     USA      Sanchez         12
# 6           CA 94114     USA   Richvalley         20

# %%
df = df.drop(df.columns[1:], 1)

# %%
df["Coordinates"]=["","","","","",""]
df
# Out:
#                                          Address Coordinates
# ID
# 1          3666 21st St, San Francisco, CA 94114
# 2        735 Dolores St, San Francisco, CA 94119
# 3   332 Hill St, San Francisco, California 94114
# 4          3995 23rd St, San Francisco, CA 94114
# 5     1056 Sanchez St, San Francisco, California
# 6       551 Alvarado St, San Francisco, CA 94114

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df
# Out:
#                                          Address  \
# ID
# 1          3666 21st St, San Francisco, CA 94114
# 2        735 Dolores St, San Francisco, CA 94119
# 3   332 Hill St, San Francisco, California 94114
# 4          3995 23rd St, San Francisco, CA 94114
# 5     1056 Sanchez St, San Francisco, California
# 6       551 Alvarado St, San Francisco, CA 94114
#
#                                           Coordinates
# ID
# 1   (3666 21st St, San Francisco, California, 9411...
# 2   (735 Dolores St, San Francisco, California, 94...
# 3   (332 Hill St, San Francisco, California, 94114...
# 4   (3995 23rd St, San Francisco, California, 9411...
# 5   (1056 Sanchez St, San Francisco, California, 9...
# 6   (551 Alvarado St, San Francisco, California, 9...

# %%
df.Coordinates[1]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.7564496899993, -122.42936434915458, 0.0))

# %%
df.set_index("Address", inplace=True)

# %%
df
# Out:
#                                                                                     Coordinates
# Address
# 3666 21st St, San Francisco, CA 94114         (3666 21st St, San Francisco, California, 9411...
# 735 Dolores St, San Francisco, CA 94119       (735 Dolores St, San Francisco, California, 94...
# 332 Hill St, San Francisco, California 94114  (332 Hill St, San Francisco, California, 94114...
# 3995 23rd St, San Francisco, CA 94114         (3995 23rd St, San Francisco, California, 9411...
# 1056 Sanchez St, San Francisco, California    (1056 Sanchez St, San Francisco, California, 9...
# 551 Alvarado St, San Francisco, CA 94114      (551 Alvarado St, San Francisco, California, 9...

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude)
df
# Out:
#                                                                                     Coordinates  \
# Address
# 3666 21st St, San Francisco, CA 94114         (3666 21st St, San Francisco, California, 9411...
# 735 Dolores St, San Francisco, CA 94119       (735 Dolores St, San Francisco, California, 94...
# 332 Hill St, San Francisco, California 94114  (332 Hill St, San Francisco, California, 94114...
# 3995 23rd St, San Francisco, CA 94114         (3995 23rd St, San Francisco, California, 9411...
# 1056 Sanchez St, San Francisco, California    (1056 Sanchez St, San Francisco, California, 9...
# 551 Alvarado St, San Francisco, CA 94114      (551 Alvarado St, San Francisco, California, 9...
#
#                                                Latitude   Longitude
# Address
# 3666 21st St, San Francisco, CA 94114         37.756450 -122.429364
# 735 Dolores St, San Francisco, CA 94119       37.757796 -122.425597
# 332 Hill St, San Francisco, California 94114  37.755648 -122.428803
# 3995 23rd St, San Francisco, CA 94114         37.752991 -122.431702
# 1056 Sanchez St, San Francisco, California    37.752129 -122.430028
# 551 Alvarado St, San Francisco, CA 94114      37.753719 -122.433240

# %%
df.drop("Coordinates", 1)
# Out:
#                                                Latitude   Longitude
# Address
# 3666 21st St, San Francisco, CA 94114         37.756450 -122.429364
# 735 Dolores St, San Francisco, CA 94119       37.757796 -122.425597
# 332 Hill St, San Francisco, California 94114  37.755648 -122.428803
# 3995 23rd St, San Francisco, CA 94114         37.752991 -122.431702
# 1056 Sanchez St, San Francisco, California    37.752129 -122.430028
# 551 Alvarado St, San Francisco, CA 94114      37.753719 -122.433240
